# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
df=pd.read_csv("D:\\exercise\\excercise_ml\\ex1data2.txt",names=["size","no:bedroom","price"])
df
# Out:
#     size  no:bedroom   price
# 0   2104           3  399900
# 1   1600           3  329900
# 2   2400           3  369000
# 3   1416           2  232000
# 4   3000           4  539900
# 5   1985           4  299900
# 6   1534           3  314900
# 7   1427           3  198999
# 8   1380           3  212000
# 9   1494           3  242500
# 10  1940           4  239999
# 11  2000           3  347000
# 12  1890           3  329999
# 13  4478           5  699900
# 14  1268           3  259900
# 15  2300           4  449900
# 16  1320           2  299900
# 17  1236           3  199900
# 18  2609           4  499998
# 19  3031           4  599000
# 20  1767           3  252900
# 21  1888           2  255000
# 22  1604           3  242900
# 23  1962           4  259900
# 24  3890           3  573900
# 25  1100           3  249900
# 26  1458           3  464500
# 27  2526           3  469000
# 28  2200           3  475000
# 29  2637           3  299900
# 30  1839           2  349900
# ...

# %%
import math
median_size = math.floor(df["size"].median())
#df['size']=df['size'].fillna(median_size)

median_size
# Out:
# 1888

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["size","no:bedroom"]],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  139.21067402, -8738.01911233])

# %%
reg.intercept_
# Out:
# 89597.90954279748

# %%
pred=reg.predict([[1800,4]])
pred
# Out:
# array([305225.04632521])
